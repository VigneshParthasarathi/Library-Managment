# %%
class book:
    def __init__(self, title, author, year, number):
        self.title = title
        self.author = author
        self.year = year
        self.serialno = number
    def display_infor(self):
        print(f"Title: {self.title}")
        print(f"Author: {self.author}")
        print(f"year: {self.year}")
        print(f"Serialno: {self.serialno}")

class Library:
    def __init__(self):
     self.book = []

    def add_book(self):
        book.title = str(input("Enter the title:"))
        book.author = str(input("Enter the author"))
        book.year = int(input("Enter the book year"))
        book.number = int(input("Enter the serial number"))
        new_book = book(book.title, book.author, book.year, book.number)
        self.book.append(new_book)
        print("Book added successfully\n")

    def show_book(self):
        serialno = int(input("Enter the Serial Number"))
        if(book.number == serialno):
            book.display_infor(self)
            print(new_book)
        else:
            print("book not found")
    def borrow_book(self):
        serialno = int(input("Enter the Serial Number"))
        if(book.number == serialno):
          book.display_infor(self)
          print("Book Borrowed")
        else:
          print("Book unavailabe")
    def  return_book(self):
        serialno = int(input("Enter the Serial Number"))
        if(book.number == serialno):
          book.display_infor(self)
          print("Book returned")
        else:
          print("Book not returned")
def main():
  while True:
   print("1. Add Book")
   print("2, Borrow Book")
   print("3, Return Book")
   print("4, Show Book info")
   print("5, Exit")
   choice = int(input("Enter the choice"))
   if (choice == 1):
     library.add_book()
   elif (choice == 2):
     library.borrow_book()
   elif (choice == 3):
     library.return_book()
   elif (choice == 4):
     library.show_book()
   elif (choice == 5):
     print("Good bye")
     break

if __name__ == "__main__":
  library = Library()
  main = main()
# Out:
# 1. Add Book
# 2, Borrow Book
# 3, Return Book
# 4, Show Book info
# 5, Exit
# Enter the choice1
# Enter the title:2
# Enter the author3
# Enter the book year4
# Enter the serial number250
# Book added successfully
#
# 1. Add Book
# 2, Borrow Book
# 3, Return Book
# 4, Show Book info
# 5, Exit
# Enter the choice2
# Enter the Serial Number23
# Book unavailabe
# 1. Add Book
# 2, Borrow Book
# 3, Return Book
# 4, Show Book info
# 5, Exit
# Enter the choice3
# Enter the Serial Number52
# Book not returned
# 1. Add Book
# 2, Borrow Book
# 3, Return Book
# 4, Show Book info
# 5, Exit
# Enter the choice4
# Enter the Serial Number56
# book not found
# 1. Add Book
# 2, Borrow Book
# 3, Return Book
# 4, Show Book info
# 5, Exit
